# %%
URL = "https://www.youtube.com/watch?v=4eq57TqYyXo"

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time
import random

# %%
# 웹드라이버 설정
browser = webdriver.Chrome()
browser.get(URL)  # 유튜브 비디오 URL 입력

time.sleep(2)  # 페이지 로딩 대기

# 댓글 섹션까지 스크롤
browser.find_element(By.TAG_NAME, 'body').send_keys(Keys.PAGE_DOWN)
time.sleep(2)  # 동적 로딩 대기

# %%
# 스크롤 다운하여 모든 댓글 로드
last_height = browser.execute_script("return document.documentElement.scrollHeight")
while True:
    browser.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(random.uniform(1.5, 3.0))  # 로딩과 다양성을 위해 랜덤 대기 시간 적용
    new_height = browser.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
# 댓글 요소 수집
comments = browser.find_elements(By.XPATH, '//*[@id="content-text"]')
usernames = browser.find_elements(By.XPATH, '//*[@id="author-text"]')
likes = browser.find_elements(By.XPATH, '//*[contains(@id, "vote-count-middle")]')
#dates = browser.find_elements(By.XPATH, '//*[@id="header-author"]//yt-formatted-string/a')
#reply_counts = browser.find_elements(By.XPATH, '//ytd-comment-thread-renderer//span[@id="vote-count-middle"]/following-sibling::span')

# DataFrame 생성
data = {
    # '작성일': [date.text for date in dates],
    '사용자이름': [username.text for username in usernames],
    'comment': [comment.text for comment in comments],
    '좋아요수': [like.text if like.text != '' else '0' for like in likes],
    # '답글수': [reply.text.split()[0] if reply.text != '' else '0' for reply in reply_counts]
}
df = pd.DataFrame(data)

# DataFrame 확인
print(df)
# Out:
#                 사용자이름                                            comment  좋아요수
# 0         @dark-zq9zt  진짜 주작 개티나네; \n경찰 사칭이면 처벌하고 \n진짜경찰이면 유튜브 복귀하고 싶...  2.1천
# 1    @user-yo3mj6dn4f  우는 게 너무 가짜 같았음..\n그냥 유튜브 접고 일반인으로 살면 될 텐데\n유튜브...    3천
# 2          @mirss3785            난 경찰이랑 여동생이랑 주작인줄알았음/너무 오랜만에 개빠게면서 쳐웃었음  1.4천
# 3        @lovres_1219                      ㅋㅋㅋㅋㅋㅋㅋㅋ이거마저 뉴스에 박제 어디까지 나락가냐   862
# 4    @user-zg3dj3vd6f  코인 안 들켰으면 팬들과 개미들 자살 여럿 했을 거다 본인 돈 벌 욕심에 사람 목숨...   270
# ..                ...                                                ...   ...
# 675       @mshxbh1234                             집에 슬리퍼가 있으니까 신었겠지 뭔 주작     0
# 676  @user-dd9ve2uz3q  오킹 구독자 어차피 160만 이하로 안떨어짐 팬카페도 여론 보면 굳건하고 ㅋㅋㅋ\n...     0
# 677  @user-ht8bi8wq9n                            감스트.오킹.김호중.라비.정준영.유아인       0
# 678  @user-fm4ry1tl9q  미개한 네티즌들아 ㅋㅋ 아무리급해도 느그집에 남이 슬리퍼 안신고들어오면 기분좋누? ...     0
# 679    @Cfsvadvasxvvs  과거 오킹은 고등학교 시절 전학가고 싶었으나 부모님이 허락해주시지 않아서 우울증이 ...     0
#
# [680 rows x 3 columns]

# %%
# pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

# plt 한국어폰트설정맥북환경 애플고딕
rc('font', family='AppleGothic')

# %%
df['comment'] = df['comment'].str.replace('[^가-힣]', ' ', regex = True)
df['comment']
# Out:
# 0      진짜 주작 개티나네   경찰 사칭이면 처벌하고  진짜경찰이면 유튜브 복귀하고 싶어서...
# 1      우는 게 너무 가짜 같았음   그냥 유튜브 접고 일반인으로 살면 될 텐데 유튜브로 ...
# 2                난 경찰이랑 여동생이랑 주작인줄알았음 너무 오랜만에 개빠게면서 쳐웃었음
# 3                                  이거마저 뉴스에 박제 어디까지 나락가냐
# 4      코인 안 들켰으면 팬들과 개미들 자살 여럿 했을 거다 본인 돈 벌 욕심에 사람 목숨...
#                              ...
# 675                               집에 슬리퍼가 있으니까 신었겠지 뭔 주작
# 676    오킹 구독자 어차피    만 이하로 안떨어짐 팬카페도 여론 보면 굳건하고     다...
# 677                              감스트 오킹 김호중 라비 정준영 유아인
# 678    미개한 네티즌들아    아무리급해도 느그집에 남이 슬리퍼 안신고들어오면 기분좋누  ...
# 679    과거 오킹은 고등학교 시절 전학가고 싶었으나 부모님이 허락해주시지 않아서 우울증이 ...
# Name: comment, Length: 680, dtype: object

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

# plt 한국어폰트설정맥북환경 애플고딕
rc('font', family='AppleGothic')

# transformers 라이브러리에서 필요한 모듈 임포트
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline

# %%
# 모델과 토크나이저 로드
model_name = "pongjin/roberta_with_kornli"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# 파이프라인 생성
nli_pipeline = pipeline("text-classification", model=model, tokenizer=tokenizer)

# %%
class ArgumentHandler():
    """
    Base interface for handling arguments for each :class:`~transformers.pipelines.Pipeline`.
    """
    def __call__(self, *args, **kwargs):
        raise NotImplementedError()


class CustomZeroShotClassificationArgumentHandler(ArgumentHandler):
    """
    Handles arguments for zero-shot for text classification by turning each possible label into an NLI
    premise/hypothesis pair.
    """

    def _parse_labels(self, labels):
        if isinstance(labels, str):
            labels = [label.strip() for label in labels.split(",")]
        return labels

    def __call__(self, sequences, labels, hypothesis_template):
        if len(labels) == 0 or len(sequences) == 0:
            raise ValueError("You must include at least one label and at least one sequence.")
        if hypothesis_template.format(labels[0]) == hypothesis_template:
            raise ValueError(
                (
                    'The provided hypothesis_template "{}" was not able to be formatted with the target labels. '
                    "Make sure the passed template includes formatting syntax such as {{}} where the label should go."
                ).format(hypothesis_template)
            )

        if isinstance(sequences, str):
            sequences = [sequences]
        labels = self._parse_labels(labels)

        sequence_pairs = []
        for label in labels:
            # 수정부: 두 문장을 페어로 입력했을 때, `token_type_ids`가 자동으로 붙는 문제를 방지하기 위해 미리 두 문장을 `sep_token` 기준으로 이어주도록 함
            sequence_pairs.append(f"{sequences} {tokenizer.sep_token} {hypothesis_template.format(label)}")

        return sequence_pairs, sequences

# %%
classifier = pipeline(
    "zero-shot-classification",
    args_parser=CustomZeroShotClassificationArgumentHandler(),
    model="pongjin/roberta_with_kornli"
)

# %%
def getLabel(comment) :
    sequence = comment
    candidate_labels = ["욕설", "도박", "자살", "약물", "음주", "흡연", "성행위"]

    # classifier(
    #     sequence,
    #     candidate_labels,
    #     hypothesis_template='이는 {}에 관한 것이다.',
    # )
    
    text = classifier(
        sequence,
        candidate_labels,
        hypothesis_template='이는 {}에 관한 것이다.',
    )
    return text['labels'], text['scores']

def visualize(res, pros, upperbound, lowerbound) :
    # 바 차트로 시각화
    plt.figure(figsize=(10, 6))
    colors = ['deepskyblue' if p != max(pros) else 'blue' for p in pros]
    plt.bar(res, pros, color=colors)
    plt.xlabel('유형')
    plt.ylabel('확률')
    plt.title('각 유형별 확률 시각화')

    # 확률의 상한선과 하한선 추가
    plt.axhline(y=upperbound, color='r', linestyle='--', label='Upper bound (0.75)')
    plt.axhline(y=lowerbound, color='r', linestyle='--', label='Lower bound (0.25)')

    plt.legend()
    plt.show()

# %%
# getLabel 함수를 각 comment에 적용하여 결과를 얻습니다.
df['Review'], df['pros'] = zip(*df['comment'].apply(getLabel))

print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 2
#       1 # getLabel 함수를 각 comment에 적용하여 결과를 얻습니다.
# ----> 2 df['Review'], df['pros'] = zip(*df['comment'].apply(getLabel))
#       4 print(df)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
# ...

# %%
df
# Out:
#                 사용자이름                                            comment  좋아요수
# 0         @dark-zq9zt  진짜 주작 개티나네   경찰 사칭이면 처벌하고  진짜경찰이면 유튜브 복귀하고 싶어서...  2.1천
# 1    @user-yo3mj6dn4f  우는 게 너무 가짜 같았음   그냥 유튜브 접고 일반인으로 살면 될 텐데 유튜브로 ...    3천
# 2          @mirss3785            난 경찰이랑 여동생이랑 주작인줄알았음 너무 오랜만에 개빠게면서 쳐웃었음  1.4천
# 3        @lovres_1219                              이거마저 뉴스에 박제 어디까지 나락가냐   862
# 4    @user-zg3dj3vd6f  코인 안 들켰으면 팬들과 개미들 자살 여럿 했을 거다 본인 돈 벌 욕심에 사람 목숨...   270
# ..                ...                                                ...   ...
# 675       @mshxbh1234                             집에 슬리퍼가 있으니까 신었겠지 뭔 주작     0
# 676  @user-dd9ve2uz3q  오킹 구독자 어차피    만 이하로 안떨어짐 팬카페도 여론 보면 굳건하고     다...     0
# 677  @user-ht8bi8wq9n                            감스트 오킹 김호중 라비 정준영 유아인       0
# 678  @user-fm4ry1tl9q  미개한 네티즌들아    아무리급해도 느그집에 남이 슬리퍼 안신고들어오면 기분좋누  ...     0
# 679    @Cfsvadvasxvvs  과거 오킹은 고등학교 시절 전학가고 싶었으나 부모님이 허락해주시지 않아서 우울증이 ...     0
#
# [680 rows x 3 columns]

# %%
def process_comments(comment, upperbound = 0.55, lowerbound=0.25):
    # 댓글로부터 레이블과 확률을 추출
    res, pros = getLabel(comment)
    
    # 첫 번째 확률을 기준으로 결정 로직 실행
    if pros[0] > upperbound:
        decision = res[0]  # 가장 높은 확률의 레이블을 반환
    elif pros[0] > lowerbound:
        decision = "판단이 어렵습니다."
    else:
        decision = "정상적인 댓글입니다."
    
    return res, pros, decision

# DataFrame에 새 열 추가
df['Review'], df['pros'], df['decision'] = zip(*df['comment'].apply(process_comments))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 21
#      18     return res, pros, decision
#      20 # DataFrame에 새 열 추가
# ---> 21 df['Review'], df['pros'], df['decision'] = zip(*df['comment'].apply(process_comments))
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
# ...

# %%
# df["decision"] 열의 각 값의 비율을 계산
decision_distribution = df["decision"].value_counts(normalize=True)
decision_distribution
# Out:
# 판단이 어렵습니다.     0.525424
# 정상적인 댓글입니다.    0.296610
# 욕설             0.064972
# 음주             0.036723
# 흡연             0.028249
# 도박             0.022599
# 자살             0.015537
# 성행위            0.008475
# 약물             0.001412
# Name: decision, dtype: float64

# %%
# "정상적인 댓글입니다."와 "판단이 어렵습니다."에 해당하지 않는 행들을 필터링
filtered_df = df[~df["decision"].isin(["정상적인 댓글입니다.", "판단이 어렵습니다."])]
filtered_df
# Out:
#                  사용자이름                                            comment  \
# 4    @fddfadae23432dsf  오킹은 이미 유튜브를 떠날 수 없음     돈은 바다와 같아서 마실수록 목마르다  ...
# 5     @user-zg3dj3vd6f  코인 안 들켰으면 팬들과 개미들 자살 여럿 했을 거다 본인 돈 벌 욕심에 사람 목숨...
# 6     @user-bq5qn8gn9r                                      뭔 트루먼쇼 하나
# 8               @epzks  누가보아도 경찰인데   누구세요      둘다 방송인이라 아무리 컴맹이라 해도 켜고...
# 21    @user-qx5tj4lp4o  진짜 스스로 무덤을 계속해서 파구나  그래도 뭐 한국이란 사회에서 조용히 있다 다시...
# ..                 ...                                                ...
# 687     @dreammaker930         그냥 방송접고 조용히 살아라  그럼 건강하게 살수있다  진짜 역겹더라 보는데
# 699   @user-um2gd3kd1i       천수 같이 국짐당 선거지원유세좀해주었으면  판새들이 알아서 무죄라도 내려줬을텐데
# 700  @Nananabanananana                얼마나 신뢰를 잃었으면 망가지는 모습까지 다들 주작으로 알까
# 702        @mshxbh1234                             집에 슬리퍼가 있으니까 신었겠지 뭔 주작
# 703        @assamram69                                   하는짓이 리재명같아서 기괴함
#
#     좋아요수                         Review  \
# 4    776  [음주, 도박, 자살, 약물, 욕설, 성행위, 흡연]
# ...

# %%
# 전체 댓글중에 어떤 비율로 각 유형의 댓글이 존재하는지 확인
filtered_df = filtered_df["decision"].value_counts(normalize=True)
filtered_df
# Out:
# 욕설     0.365079
# 음주     0.206349
# 흡연     0.158730
# 도박     0.126984
# 자살     0.087302
# 성행위    0.047619
# 약물     0.007937
# Name: decision, dtype: float64
